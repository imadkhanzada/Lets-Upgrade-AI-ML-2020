# %% [markdown]
# Question 1:
# Write a program to copy the contents of one file to another using a for loop. (Don’t use built-in copy
# function)

# %%
fn = open('mad.txt','r') 
  
fn1 = open('nfile.txt','w') 
  
cont = fn.readlines() 

for i in range(0, len(cont)): 
     fn1.write(cont[i]) 
   
fn1.close() 

fn1 = open('nfile.txt','r') 
  
cont1 = fn1.read()  
print(cont1) 
  
fn.close() 
fn1.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-fcc8725b96ec> in <module>()
# ----> 1 fn = open('mad.txt','r')
#       2
#       3 fn1 = open('nfile.txt','w')
#       4
#       5 cont = fn.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mad.txt'

# %% [markdown]
# Question 2:
# Write a Python program to find maximum and minimum values in the dictionary. Do not use built-in min
# and max functions.

# %%
x = {'a':28,'b':12,'c':11}

list_of_values = list(x.values())
list_of_values.sort()
print('Minimum value is %s\n\nMaximum value is %s'%(list_of_values[0],list_of_values[-1]))
# Out:
# Minimum value is 11
#
# Maximum value is 28
